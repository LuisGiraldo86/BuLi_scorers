# %% [markdown]
# # Getting country names in German and English

# %%
# imports
import pandas as pd

# %%
# path to data
FIFA_ISO = '/mnt/287A29DF7A29AA90/PythonProjects/projects_repo/BuLi_scorers/data/FIFA_ISO_codes.csv'
FIFA_GERMAN = '/mnt/287A29DF7A29AA90/PythonProjects/projects_repo/BuLi_scorers/data/FIFA_codes.csv'

# %%
# load data
df_fifa_iso = pd.read_csv(FIFA_ISO)
df_fifa_ger = pd.read_csv(FIFA_GERMAN)

# %%
# selecting columns
df_fifa_ger = df_fifa_ger[['Staat', 'FIFA code', 'Konföderation']].copy()
df_fifa_ger
# Out:
#                             Staat FIFA code Konföderation
# 0                     Afghanistan       AFG           AFC
# 1                         Ägypten       EGY           CAF
# 2                        Albanien       ALB          UEFA
# 3                        Algerien       ALG           CAF
# 4              Amerikanisch-Samoa       ASA           OFC
# ..                            ...       ...           ...
# 206            Vereinigte Staaten       USA      CONCACAF
# 207                       Vietnam       VIE           AFC
# 208                         Wales       WAL          UEFA
# 209  Zentralafrikanische Republik       CTA           CAF
# 210                        Zypern       CYP          UEFA
#
# [211 rows x 3 columns]

# %%
df_fifa = df_fifa_ger.merge(df_fifa_iso, on='FIFA code')
df_fifa
# Out:
#                             Staat FIFA code Konföderation  \
# 0                     Afghanistan       AFG           AFC
# 1                         Ägypten       EGY           CAF
# 2                        Albanien       ALB          UEFA
# 3                        Algerien       ALG           CAF
# 4              Amerikanisch-Samoa       ASA           OFC
# ..                            ...       ...           ...
# 205            Vereinigte Staaten       USA      CONCACAF
# 206                       Vietnam       VIE           AFC
# 207                         Wales       WAL          UEFA
# 208  Zentralafrikanische Republik       CTA           CAF
# 209                        Zypern       CYP          UEFA
#
#                       Country IOC code ISO code
# 0                 Afghanistan      AFG      AFG
# 1                       Egypt      EGY      EGY
# 2                     Albania      ALB      ALB
# 3                     Algeria      ALG      DZA
# ...
